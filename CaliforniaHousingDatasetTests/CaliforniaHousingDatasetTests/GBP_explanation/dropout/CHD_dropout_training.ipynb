# %% [markdown]
# ## Summary of the notebook
#
# **train configuration**: <br>
# eager execution = enabled
#
# **process**:
# 1. Define the model and fit the model using the train, validation and test data
# 2. Save the trained model at specified path
# 3. Use the trained model variable and pass it to the StochasticRegressor class
# 4. From the object returned in 3., access the predict_output() by passing the test data and number of samples desired. This function returns the samples, pred mean and pred std
# 5. Plot the prediction mean and +-1 std dev against the ground truth to visualize the performance of the model
#
# **critical points and checklist**
# 1. the script should yield a trained model
# 2. pdfs and pngs in the output plots folder
# 3. check model training configuration once
#
# **analysis**
# 1. for num_samples = 20 and a single input record (of shape (1,8)) <br>
# intermediate samples shape : (20, 1, 1) <br>
# final mean and std/varshape : (1, 1)

# %% [markdown]
# ## Mount the drive

# %%
# mount the drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Setting the correct path

# %%
import os

project_path = '/content/drive/MyDrive/MasterThesis'
task_name = 'CaliforniaHousingDatasetTests'
exp_name = 'GBP_explanation'
uncert_name = 'dropout'

# %cd /content/drive/MyDrive/MasterThesis/ 

print(os.getcwd())
path = project_path + '/' + task_name + '/' + exp_name + '/' + uncert_name + '/' # 'CaliforniaHousingDatasetTests/GBP_explanation/flipout/'
print(path)
# Out:
# /content/drive/MyDrive/MasterThesis
# /content/drive/MyDrive/MasterThesis
# /content/drive/MyDrive/MasterThesis/CaliforniaHousingDatasetTests/GBP_explanation/dropout/

# %% [markdown]
# ## Removing previous trained models

# %%
list_of_files = os.listdir(os.path.join(path, 'saved_models'))
print(path)

for item in list_of_files:
    if item.endswith('.h5'):
        print(f'deleting {item}')
        os.remove(os.path.join(path, 'saved_models', item))
# Out:
# /content/drive/MyDrive/MasterThesis/CaliforniaHousingDatasetTests/GBP_explanation/dropout/
# deleting model_epochs_200_num_samples_10.h5

# %% [markdown]
# ## Imports

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import tensorflow as tf
import keras

import os
import random 
import math

from keras.layers import *
from keras.models import Model, Sequential
import keras.backend as K

print(tf.__version__)
print(f'Eager execution enabled : {tf.executing_eagerly()}')

import sys
sys.path.insert(0,'/content/drive/My Drive/MasterThesis/src/')

from utils import *
# Out:
# 2.8.2
# Eager execution enabled : True

# %% [markdown]
# ## Load data

# %%
train_data, train_labels, val_data, val_labels, test_data, test_labels, feature_names = load_california_housing_data()

# check to ensure the functionality of load function 
#print(train_labels[20])
#print(val_labels[30])
#print(test_labels[40])
# Out:
# ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']
# Training data shape
#  (12750, 8)
# Training labels shape
#  (12750, 1)
# Validation data shape
#   (4250, 8)
# Validation labels shape
#   (4250, 1)
# Test data shape
#   (3000, 8)
# Test labels shape
#   (3000, 1)

# %% [markdown]
# ## Class definitions

# %% [markdown]
# ### StochasticModel & StochasticRegressor

# %%
import numpy as np
import tensorflow as tf 
import tensorflow.keras.backend as K

Layer = tf.keras.layers.Layer
Dropout = tf.keras.layers.Dropout


class StochasticDropout(Dropout):
    """
        Applies Dropout to the input, independent of the training phase.
        Used to easily implement MC-Dropout. It is a drop-in replacement for
        the standard Keras Dropout layer, but note that this layer applies
        dropout at the training and inference phases.
    """
    def __init__(self, rate, noise_shape=None, seed=None, **kwargs):
        super(StochasticDropout, self).__init__(rate, noise_shape, seed, **kwargs)
    
    def call(self, inputs, training=None):
        if 0. < self.rate < 1.:
            noise_shape = self._get_noise_shape(inputs)

            return K.dropout(inputs, self.rate, noise_shape, seed=self.seed)

        return inputs

    def get_config(self):
        # this code is added so that the model can be saved even after making use of a custom layer 
        # https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object
        config = super(StochasticDropout, self).get_config()
        config.update({'rate': self.rate})
        return config


class StochasticModel:
    """
        Stochastic model, requiring several forward passes to produce an estimate of the posterior predictive distribution.
        This class just wraps a keras model to enable dropout at inference time.
    """
    def __init__(self, model, num_samples=10, **kwargs):
        """
            Builds a stochastic model from a keras model. The model should already be trained.
        """
        self.model = model
        self.num_samples = num_samples
    
    def predict_samples(self, x, num_samples=None, batch_size=32, multi_output=False, **kwargs):
        """
            Performs num_samples predictions using the model, and returns the produced output samples.
        """

        if num_samples is None:
            num_samples = self.num_samples

        assert num_samples > 0
        samples = [None] * num_samples

        if "verbose" not in kwargs:
            kwargs["verbose"] = 0

        for i in range(num_samples):
            samples[i] = self.model.predict(x, batch_size=1, **kwargs)

        if multi_output:
            return samples
        else:
            return np.array(samples)
            
            
class  StochasticRegressor(StochasticModel):
    def __init__(self, model, num_samples=10, **kwargs):
        # https://stackoverflow.com/questions/62280161/saving-keras-models-with-custom-layers
        super().__init__(model, num_samples)
        self.input = self.model.input
        self.output = self.model.output

    def predict_output(self, inp, num_samples=None, batch_size=32, output_scaler=None, **kwargs):
        """
            Performs a prediction  given input inp using MC Dropout, and returns the mean and standard deviation of the model output.
        """
        samples = self.predict_samples(inp, num_samples, batch_size=batch_size, **kwargs)

        if output_scaler is not None:
            samples = list(map(lambda x: output_scaler.inverse_transform(x), samples))
        
        print('intermediate samples shape ', samples.shape)

        mean_pred = np.mean(samples, axis=0)
        std_pred = np.std(samples, axis=0)

        return samples, mean_pred, std_pred 

    def save(self, path):
        # stochaticmodel class does not have basic tf function like save(), summary(), get_layer() and so on 
        # https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object
        self.model.save(path)

    def summary(self):
        return self.model.summary()  

    def evaluate(self, test_data):
        return self.model.evaluate(test_data)

    def get_layer(self, name=None, index=None):
        # the get_layer() has been taken from ths following source 
        # https://github.com/keras-team/keras/blob/v2.8.0/keras/engine/training.py#L2797-L2831
    
        """Retrieves a layer based on either its name (unique) or index.
        If `name` and `index` are both provided, `index` will take precedence.
        Indices are based on order of horizontal graph traversal (bottom-up).
        Args:
            name: String, name of layer.
            index: Integer, index of layer.
        Returns:
            A layer instance.
        """
        # TODO(fchollet): We could build a dictionary based on layer names
        # since they are constant, but we have not done that yet.
        if index is not None and name is not None:
            raise ValueError('Provide only a layer name or a layer index. Received: '
                        f'index={index}, name={name}.')

        if index is not None:
            if len(self.layers) <= index:
                raise ValueError(f'Was asked to retrieve layer at index {index}'
                            f' but model only has {len(self.layers)}'
                            ' layers.')
            else:
                return self.model.layers[index]

        if name is not None:
            for layer in self.model.layers:
                if layer.name == name:
                    return layer
            raise ValueError(f'No such layer: {name}. Existing layers are: '
                        f'{list(layer.name for layer in self.model.layers)}.')
        raise ValueError('Provide either a layer name or layer index at '
                     '`get_layer`.')

# %% [markdown]
# ## Vanilla MLP (just to get the architecture to print in the report)

# %%
model = Sequential()
model.add(Input(shape=(8, )))

model.add(Dense(8, activation='relu'))
#model.add(StochasticDropout(prob))
model.add(Dense(8, activation='relu'))
#model.add(StochasticDropout(prob))
model.add(Dense(8, activation='relu'))
#model.add(StochasticDropout(prob))
   
model.add(Dense(1, activation='relu'))

model.compile(loss='mse', optimizer='rmsprop', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 72
#
#  dense_1 (Dense)             (None, 8)                 72
#
#  dense_2 (Dense)             (None, 8)                 72
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Define and train dropout model [check if this is the correct model]

# %%
# DROPOUT MODEL
def train_model(x_train, y_train, x_val, y_val, x_test, epochs, num_samples, prob, train_batch_size, validation_batch_size, test_batch_size):
    #obtained from hyperparameter optimization
    K.clear_session()
    model = Sequential()
    model.add(Input(shape=(8, )))

    model.add(Dense(8, activation='relu'))
    #model.add(StochasticDropout(prob))
    model.add(Dense(8, activation='relu'))
    model.add(StochasticDropout(prob))
    model.add(Dense(8, activation='relu'))
    model.add(StochasticDropout(prob))
   
    model.add(Dense(1, activation='relu'))

    model.compile(loss='mse', optimizer='rmsprop', metrics=['mae'])

    def adapt_learning_rate(epoch):
        if epoch<50:
            return 1e-3
        elif epoch>50 and epoch<75:
            return 1e-4 
        else:
            return 1e-5

    lr_scheduler = keras.callbacks.LearningRateScheduler(adapt_learning_rate)
    #ckpt = keras.callbacks.ModelCheckpoint(filepath=path+uncert_name+'_model_epochs_'+str(epochs)+'_num_samples_'+str(num_samples)+'_epochs_{epoch:02d}_val_loss_{val_loss:.3f}.h5',
    #                                       monitor='val_loss',
    #                                       verbose=0,
    #                                       save_best_only=True,
    #                                       mode='auto')
                                           

    # train a model with stochasticdropout() layer
    history = model.fit(x_train, 
                        y_train, 
                        batch_size=train_batch_size,
                        validation_data=(x_val, y_val), 
                        validation_batch_size=validation_batch_size,
                        verbose=2, 
                        epochs=epochs)
                        #callbacks=[lr_scheduler])
                        #callbacks=[lr_scheduler, ckpt])
    
    #saving the model that has custom layers
    model.save(os.path.join(path, 'saved_models', 'model_epochs_'+str(epochs)+'_num_samples_'+str(num_samples)+'.h5') )
    model.summary()

    # plotting the training and validation curves
    plt.plot(history.history['loss'], label='train loss')
    plt.plot(history.history['val_loss'], label='val loss')
    plt.legend()
    plt.grid()
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.title('loss curves')
    plt.show()

    plt.plot(history.history['mae'], label='train mae')
    plt.plot(history.history['val_mae'], label='val mae')
    plt.legend()
    plt.grid()
    plt.xlabel('epochs')
    plt.ylabel('mae')
    plt.title('mae curves')
    plt.show()

    # call the stochasticregressor class and pass the trained model that contains the stochasticdropout layer 
    mc_model = StochasticRegressor(model)
    pred_samples, pred_mean, pred_std = mc_model.predict_output(x_test, num_samples=num_samples, batch_size=test_batch_size)
    print('pred_samples shape ', pred_samples.shape)
    print('pred_mean shape ', pred_mean.shape)
    print('pred_std shape ', pred_std.shape)

    # return the predicted_samples, predicted_mean, predicted_std and model 
    return pred_samples, pred_mean, pred_std, mc_model


epochs=200
num_samples=10
prob=0.3
train_batch_size=4096
validation_batch_size=4096
test_batch_size=4096 
# running this command creates the stochastic dropout model, trains it and generates the predicted_samples, predicted_mean and predicted_std for the test set (all 3000 examples)
prediction_samples, prediction_mean, prediction_std, stochastic_model = train_model(train_data, 
                                                                                    train_labels, 
                                                                                    val_data, 
                                                                                    val_labels, 
                                                                                    test_data, 
                                                                                    epochs=epochs, 
                                                                                    num_samples=num_samples, 
                                                                                    prob=prob,
                                                                                    train_batch_size=train_batch_size, 
                                                                                    validation_batch_size=validation_batch_size, 
                                                                                    test_batch_size=test_batch_size)
print('prediction mean :\n', prediction_mean)
print('prediction mean shape ', prediction_mean.shape)
print('prediction std :\n', prediction_std)
print('prediction std shape ', prediction_std.shape)
print('prediction samples :\n', prediction_samples)
print('prediction samples shape ', prediction_samples.shape)
# Out:
# Epoch 1/200
# 4/4 - 1s - loss: 0.1368 - mae: 0.2931 - val_loss: 0.1205 - val_mae: 0.2674 - 1s/epoch - 305ms/step
# Epoch 2/200
# 4/4 - 0s - loss: 0.1096 - mae: 0.2531 - val_loss: 0.0999 - val_mae: 0.2395 - 54ms/epoch - 14ms/step
# Epoch 3/200
# 4/4 - 0s - loss: 0.0937 - mae: 0.2316 - val_loss: 0.0872 - val_mae: 0.2232 - 45ms/epoch - 11ms/step
# Epoch 4/200
# 4/4 - 0s - loss: 0.0849 - mae: 0.2201 - val_loss: 0.0818 - val_mae: 0.2180 - 68ms/epoch - 17ms/step
# Epoch 5/200
# 4/4 - 0s - loss: 0.0794 - mae: 0.2134 - val_loss: 0.0793 - val_mae: 0.2113 - 64ms/epoch - 16ms/step
# Epoch 6/200
# 4/4 - 0s - loss: 0.0750 - mae: 0.2072 - val_loss: 0.0738 - val_mae: 0.2037 - 69ms/epoch - 17ms/step
# Epoch 7/200
# 4/4 - 0s - loss: 0.0728 - mae: 0.2045 - val_loss: 0.0705 - val_mae: 0.2009 - 85ms/epoch - 21ms/step
# Epoch 8/200
# 4/4 - 0s - loss: 0.0698 - mae: 0.2000 - val_loss: 0.0695 - val_mae: 0.1954 - 47ms/epoch - 12ms/step
# Epoch 9/200
# 4/4 - 0s - loss: 0.0673 - mae: 0.1957 - val_loss: 0.0664 - val_mae: 0.1943 - 68ms/epoch - 17ms/step
# Epoch 10/200
# 4/4 - 0s - loss: 0.0642 - mae: 0.1928 - val_loss: 0.0638 - val_mae: 0.1894 - 100ms/epoch - 25ms/step
# Epoch 11/200
# 4/4 - 0s - loss: 0.0633 - mae: 0.1905 - val_loss: 0.0608 - val_mae: 0.1842 - 89ms/epoch - 22ms/step
# Epoch 12/200
# 4/4 - 0s - loss: 0.0612 - mae: 0.1877 - val_loss: 0.0629 - val_mae: 0.1878 - 74ms/epoch - 18ms/step
# Epoch 13/200
# 4/4 - 0s - loss: 0.0597 - mae: 0.1847 - val_loss: 0.0585 - val_mae: 0.1809 - 71ms/epoch - 18ms/step
# Epoch 14/200
# 4/4 - 0s - loss: 0.0568 - mae: 0.1796 - val_loss: 0.0576 - val_mae: 0.1802 - 67ms/epoch - 17ms/step
# Epoch 15/200
# 4/4 - 0s - loss: 0.0571 - mae: 0.1801 - val_loss: 0.0550 - val_mae: 0.1744 - 46ms/epoch - 12ms/step
# Epoch 16/200
# 4/4 - 0s - loss: 0.0544 - mae: 0.1755 - val_loss: 0.0550 - val_mae: 0.1755 - 43ms/epoch - 11ms/step
# Epoch 17/200
# 4/4 - 0s - loss: 0.0535 - mae: 0.1753 - val_loss: 0.0544 - val_mae: 0.1762 - 88ms/epoch - 22ms/step
# Epoch 18/200
# 4/4 - 0s - loss: 0.0525 - mae: 0.1735 - val_loss: 0.0537 - val_mae: 0.1736 - 74ms/epoch - 18ms/step
# Epoch 19/200
# 4/4 - 0s - loss: 0.0517 - mae: 0.1719 - val_loss: 0.0548 - val_mae: 0.1749 - 64ms/epoch - 16ms/step
# Epoch 20/200
# 4/4 - 0s - loss: 0.0498 - mae: 0.1685 - val_loss: 0.0513 - val_mae: 0.1697 - 70ms/epoch - 17ms/step
# Epoch 21/200
# 4/4 - 0s - loss: 0.0493 - mae: 0.1671 - val_loss: 0.0503 - val_mae: 0.1674 - 59ms/epoch - 15ms/step
# Epoch 22/200
# 4/4 - 0s - loss: 0.0483 - mae: 0.1655 - val_loss: 0.0490 - val_mae: 0.1662 - 50ms/epoch - 13ms/step
# Epoch 23/200
# 4/4 - 0s - loss: 0.0476 - mae: 0.1651 - val_loss: 0.0481 - val_mae: 0.1653 - 113ms/epoch - 28ms/step
# Epoch 24/200
# 4/4 - 0s - loss: 0.0473 - mae: 0.1645 - val_loss: 0.0481 - val_mae: 0.1629 - 42ms/epoch - 11ms/step
# Epoch 25/200
# 4/4 - 0s - loss: 0.0461 - mae: 0.1609 - val_loss: 0.0466 - val_mae: 0.1625 - 40ms/epoch - 10ms/step
# Epoch 26/200
# 4/4 - 0s - loss: 0.0461 - mae: 0.1618 - val_loss: 0.0469 - val_mae: 0.1607 - 84ms/epoch - 21ms/step
# Epoch 27/200
# 4/4 - 0s - loss: 0.0440 - mae: 0.1582 - val_loss: 0.0455 - val_mae: 0.1595 - 69ms/epoch - 17ms/step
# Epoch 28/200
# 4/4 - 0s - loss: 0.0443 - mae: 0.1584 - val_loss: 0.0452 - val_mae: 0.1610 - 61ms/epoch - 15ms/step
# Epoch 29/200
# 4/4 - 0s - loss: 0.0436 - mae: 0.1578 - val_loss: 0.0460 - val_mae: 0.1597 - 55ms/epoch - 14ms/step
# Epoch 30/200
# 4/4 - 0s - loss: 0.0432 - mae: 0.1564 - val_loss: 0.0449 - val_mae: 0.1568 - 56ms/epoch - 14ms/step
# Epoch 31/200
# 4/4 - 0s - loss: 0.0429 - mae: 0.1548 - val_loss: 0.0445 - val_mae: 0.1566 - 63ms/epoch - 16ms/step
# Epoch 32/200
# 4/4 - 0s - loss: 0.0422 - mae: 0.1547 - val_loss: 0.0422 - val_mae: 0.1540 - 42ms/epoch - 11ms/step
# Epoch 33/200
# 4/4 - 0s - loss: 0.0413 - mae: 0.1529 - val_loss: 0.0421 - val_mae: 0.1537 - 49ms/epoch - 12ms/step
# Epoch 34/200
# 4/4 - 0s - loss: 0.0405 - mae: 0.1512 - val_loss: 0.0395 - val_mae: 0.1504 - 46ms/epoch - 12ms/step
# Epoch 35/200
# 4/4 - 0s - loss: 0.0410 - mae: 0.1520 - val_loss: 0.0403 - val_mae: 0.1513 - 41ms/epoch - 10ms/step
# Epoch 36/200
# 4/4 - 0s - loss: 0.0407 - mae: 0.1516 - val_loss: 0.0423 - val_mae: 0.1531 - 41ms/epoch - 10ms/step
# Epoch 37/200
# 4/4 - 0s - loss: 0.0406 - mae: 0.1498 - val_loss: 0.0408 - val_mae: 0.1495 - 40ms/epoch - 10ms/step
# Epoch 38/200
# 4/4 - 0s - loss: 0.0389 - mae: 0.1467 - val_loss: 0.0403 - val_mae: 0.1491 - 43ms/epoch - 11ms/step
# Epoch 39/200
# 4/4 - 0s - loss: 0.0399 - mae: 0.1488 - val_loss: 0.0404 - val_mae: 0.1479 - 72ms/epoch - 18ms/step
# Epoch 40/200
# 4/4 - 0s - loss: 0.0398 - mae: 0.1480 - val_loss: 0.0405 - val_mae: 0.1489 - 68ms/epoch - 17ms/step
# Epoch 41/200
# 4/4 - 0s - loss: 0.0388 - mae: 0.1471 - val_loss: 0.0386 - val_mae: 0.1449 - 42ms/epoch - 11ms/step
# Epoch 42/200
# 4/4 - 0s - loss: 0.0386 - mae: 0.1451 - val_loss: 0.0391 - val_mae: 0.1448 - 57ms/epoch - 14ms/step
# Epoch 43/200
# 4/4 - 0s - loss: 0.0384 - mae: 0.1441 - val_loss: 0.0405 - val_mae: 0.1461 - 55ms/epoch - 14ms/step
# Epoch 44/200
# 4/4 - 0s - loss: 0.0390 - mae: 0.1453 - val_loss: 0.0385 - val_mae: 0.1453 - 55ms/epoch - 14ms/step
# Epoch 45/200
# 4/4 - 0s - loss: 0.0376 - mae: 0.1431 - val_loss: 0.0377 - val_mae: 0.1431 - 46ms/epoch - 11ms/step
# Epoch 46/200
# 4/4 - 0s - loss: 0.0381 - mae: 0.1454 - val_loss: 0.0377 - val_mae: 0.1444 - 44ms/epoch - 11ms/step
# Epoch 47/200
# 4/4 - 0s - loss: 0.0368 - mae: 0.1424 - val_loss: 0.0383 - val_mae: 0.1446 - 67ms/epoch - 17ms/step
# Epoch 48/200
# 4/4 - 0s - loss: 0.0368 - mae: 0.1421 - val_loss: 0.0386 - val_mae: 0.1438 - 42ms/epoch - 10ms/step
# Epoch 49/200
# 4/4 - 0s - loss: 0.0364 - mae: 0.1409 - val_loss: 0.0371 - val_mae: 0.1426 - 48ms/epoch - 12ms/step
# Epoch 50/200
# 4/4 - 0s - loss: 0.0365 - mae: 0.1409 - val_loss: 0.0360 - val_mae: 0.1414 - 42ms/epoch - 10ms/step
# Epoch 51/200
# 4/4 - 0s - loss: 0.0361 - mae: 0.1411 - val_loss: 0.0370 - val_mae: 0.1414 - 59ms/epoch - 15ms/step
# Epoch 52/200
# 4/4 - 0s - loss: 0.0359 - mae: 0.1404 - val_loss: 0.0355 - val_mae: 0.1379 - 69ms/epoch - 17ms/step
# Epoch 53/200
# 4/4 - 0s - loss: 0.0347 - mae: 0.1375 - val_loss: 0.0361 - val_mae: 0.1393 - 75ms/epoch - 19ms/step
# Epoch 54/200
# 4/4 - 0s - loss: 0.0350 - mae: 0.1375 - val_loss: 0.0362 - val_mae: 0.1395 - 49ms/epoch - 12ms/step
# Epoch 55/200
# 4/4 - 0s - loss: 0.0346 - mae: 0.1374 - val_loss: 0.0359 - val_mae: 0.1389 - 51ms/epoch - 13ms/step
# Epoch 56/200
# 4/4 - 0s - loss: 0.0336 - mae: 0.1352 - val_loss: 0.0362 - val_mae: 0.1386 - 70ms/epoch - 18ms/step
# Epoch 57/200
# 4/4 - 0s - loss: 0.0347 - mae: 0.1363 - val_loss: 0.0369 - val_mae: 0.1394 - 64ms/epoch - 16ms/step
# Epoch 58/200
# 4/4 - 0s - loss: 0.0340 - mae: 0.1356 - val_loss: 0.0347 - val_mae: 0.1376 - 48ms/epoch - 12ms/step
# Epoch 59/200
# 4/4 - 0s - loss: 0.0343 - mae: 0.1368 - val_loss: 0.0349 - val_mae: 0.1367 - 86ms/epoch - 21ms/step
# Epoch 60/200
# 4/4 - 0s - loss: 0.0344 - mae: 0.1366 - val_loss: 0.0354 - val_mae: 0.1369 - 59ms/epoch - 15ms/step
# Epoch 61/200
# 4/4 - 0s - loss: 0.0340 - mae: 0.1361 - val_loss: 0.0335 - val_mae: 0.1350 - 58ms/epoch - 15ms/step
# Epoch 62/200
# 4/4 - 0s - loss: 0.0333 - mae: 0.1344 - val_loss: 0.0340 - val_mae: 0.1352 - 39ms/epoch - 10ms/step
# Epoch 63/200
# 4/4 - 0s - loss: 0.0338 - mae: 0.1366 - val_loss: 0.0337 - val_mae: 0.1345 - 45ms/epoch - 11ms/step
# Epoch 64/200
# 4/4 - 0s - loss: 0.0331 - mae: 0.1343 - val_loss: 0.0333 - val_mae: 0.1344 - 45ms/epoch - 11ms/step
# Epoch 65/200
# 4/4 - 0s - loss: 0.0335 - mae: 0.1356 - val_loss: 0.0357 - val_mae: 0.1370 - 49ms/epoch - 12ms/step
# Epoch 66/200
# 4/4 - 0s - loss: 0.0334 - mae: 0.1341 - val_loss: 0.0324 - val_mae: 0.1335 - 53ms/epoch - 13ms/step
# Epoch 67/200
# 4/4 - 0s - loss: 0.0325 - mae: 0.1334 - val_loss: 0.0330 - val_mae: 0.1340 - 110ms/epoch - 27ms/step
# Epoch 68/200
# 4/4 - 0s - loss: 0.0325 - mae: 0.1326 - val_loss: 0.0333 - val_mae: 0.1333 - 52ms/epoch - 13ms/step
# Epoch 69/200
# 4/4 - 0s - loss: 0.0329 - mae: 0.1336 - val_loss: 0.0327 - val_mae: 0.1328 - 46ms/epoch - 11ms/step
# Epoch 70/200
# 4/4 - 0s - loss: 0.0324 - mae: 0.1331 - val_loss: 0.0323 - val_mae: 0.1322 - 45ms/epoch - 11ms/step
# Epoch 71/200
# 4/4 - 0s - loss: 0.0319 - mae: 0.1322 - val_loss: 0.0317 - val_mae: 0.1309 - 94ms/epoch - 24ms/step
# Epoch 72/200
# 4/4 - 0s - loss: 0.0317 - mae: 0.1317 - val_loss: 0.0326 - val_mae: 0.1322 - 97ms/epoch - 24ms/step
# Epoch 73/200
# 4/4 - 0s - loss: 0.0316 - mae: 0.1314 - val_loss: 0.0333 - val_mae: 0.1326 - 88ms/epoch - 22ms/step
# Epoch 74/200
# 4/4 - 0s - loss: 0.0311 - mae: 0.1297 - val_loss: 0.0328 - val_mae: 0.1315 - 44ms/epoch - 11ms/step
# Epoch 75/200
# 4/4 - 0s - loss: 0.0310 - mae: 0.1294 - val_loss: 0.0332 - val_mae: 0.1323 - 72ms/epoch - 18ms/step
# Epoch 76/200
# 4/4 - 0s - loss: 0.0305 - mae: 0.1295 - val_loss: 0.0324 - val_mae: 0.1317 - 46ms/epoch - 12ms/step
# Epoch 77/200
# 4/4 - 0s - loss: 0.0314 - mae: 0.1298 - val_loss: 0.0320 - val_mae: 0.1313 - 40ms/epoch - 10ms/step
# Epoch 78/200
# 4/4 - 0s - loss: 0.0313 - mae: 0.1306 - val_loss: 0.0308 - val_mae: 0.1295 - 52ms/epoch - 13ms/step
# Epoch 79/200
# 4/4 - 0s - loss: 0.0306 - mae: 0.1298 - val_loss: 0.0304 - val_mae: 0.1306 - 45ms/epoch - 11ms/step
# Epoch 80/200
# 4/4 - 0s - loss: 0.0307 - mae: 0.1310 - val_loss: 0.0318 - val_mae: 0.1301 - 40ms/epoch - 10ms/step
# Epoch 81/200
# 4/4 - 0s - loss: 0.0308 - mae: 0.1281 - val_loss: 0.0315 - val_mae: 0.1305 - 39ms/epoch - 10ms/step
# Epoch 82/200
# 4/4 - 0s - loss: 0.0309 - mae: 0.1292 - val_loss: 0.0309 - val_mae: 0.1284 - 49ms/epoch - 12ms/step
# Epoch 83/200
# 4/4 - 0s - loss: 0.0304 - mae: 0.1288 - val_loss: 0.0320 - val_mae: 0.1303 - 42ms/epoch - 11ms/step
# Epoch 84/200
# 4/4 - 0s - loss: 0.0305 - mae: 0.1288 - val_loss: 0.0325 - val_mae: 0.1308 - 48ms/epoch - 12ms/step
# Epoch 85/200
# 4/4 - 0s - loss: 0.0303 - mae: 0.1278 - val_loss: 0.0314 - val_mae: 0.1300 - 51ms/epoch - 13ms/step
# Epoch 86/200
# 4/4 - 0s - loss: 0.0299 - mae: 0.1285 - val_loss: 0.0314 - val_mae: 0.1295 - 46ms/epoch - 11ms/step
# Epoch 87/200
# 4/4 - 0s - loss: 0.0302 - mae: 0.1283 - val_loss: 0.0310 - val_mae: 0.1296 - 46ms/epoch - 11ms/step
# Epoch 88/200
# 4/4 - 0s - loss: 0.0301 - mae: 0.1281 - val_loss: 0.0302 - val_mae: 0.1290 - 50ms/epoch - 12ms/step
# Epoch 89/200
# 4/4 - 0s - loss: 0.0302 - mae: 0.1287 - val_loss: 0.0321 - val_mae: 0.1302 - 47ms/epoch - 12ms/step
# Epoch 90/200
# 4/4 - 0s - loss: 0.0303 - mae: 0.1282 - val_loss: 0.0340 - val_mae: 0.1338 - 84ms/epoch - 21ms/step
# Epoch 91/200
# 4/4 - 0s - loss: 0.0297 - mae: 0.1274 - val_loss: 0.0317 - val_mae: 0.1309 - 64ms/epoch - 16ms/step
# Epoch 92/200
# 4/4 - 0s - loss: 0.0298 - mae: 0.1273 - val_loss: 0.0324 - val_mae: 0.1307 - 41ms/epoch - 10ms/step
# Epoch 93/200
# 4/4 - 0s - loss: 0.0295 - mae: 0.1265 - val_loss: 0.0319 - val_mae: 0.1307 - 39ms/epoch - 10ms/step
# Epoch 94/200
# 4/4 - 0s - loss: 0.0298 - mae: 0.1276 - val_loss: 0.0338 - val_mae: 0.1333 - 85ms/epoch - 21ms/step
# Epoch 95/200
# 4/4 - 0s - loss: 0.0296 - mae: 0.1260 - val_loss: 0.0313 - val_mae: 0.1292 - 47ms/epoch - 12ms/step
# Epoch 96/200
# 4/4 - 0s - loss: 0.0294 - mae: 0.1267 - val_loss: 0.0313 - val_mae: 0.1287 - 43ms/epoch - 11ms/step
# Epoch 97/200
# 4/4 - 0s - loss: 0.0298 - mae: 0.1272 - val_loss: 0.0318 - val_mae: 0.1298 - 58ms/epoch - 14ms/step
# Epoch 98/200
# 4/4 - 0s - loss: 0.0294 - mae: 0.1269 - val_loss: 0.0306 - val_mae: 0.1289 - 48ms/epoch - 12ms/step
# Epoch 99/200
# 4/4 - 0s - loss: 0.0292 - mae: 0.1272 - val_loss: 0.0297 - val_mae: 0.1274 - 56ms/epoch - 14ms/step
# Epoch 100/200
# 4/4 - 0s - loss: 0.0296 - mae: 0.1277 - val_loss: 0.0310 - val_mae: 0.1287 - 85ms/epoch - 21ms/step
# Epoch 101/200
# 4/4 - 0s - loss: 0.0293 - mae: 0.1264 - val_loss: 0.0297 - val_mae: 0.1260 - 110ms/epoch - 28ms/step
# Epoch 102/200
# 4/4 - 0s - loss: 0.0296 - mae: 0.1273 - val_loss: 0.0323 - val_mae: 0.1311 - 121ms/epoch - 30ms/step
# Epoch 103/200
# 4/4 - 0s - loss: 0.0291 - mae: 0.1261 - val_loss: 0.0303 - val_mae: 0.1282 - 88ms/epoch - 22ms/step
# Epoch 104/200
# 4/4 - 0s - loss: 0.0289 - mae: 0.1264 - val_loss: 0.0321 - val_mae: 0.1323 - 47ms/epoch - 12ms/step
# Epoch 105/200
# 4/4 - 0s - loss: 0.0290 - mae: 0.1257 - val_loss: 0.0330 - val_mae: 0.1327 - 60ms/epoch - 15ms/step
# Epoch 106/200
# 4/4 - 0s - loss: 0.0291 - mae: 0.1262 - val_loss: 0.0329 - val_mae: 0.1333 - 73ms/epoch - 18ms/step
# Epoch 107/200
# 4/4 - 0s - loss: 0.0285 - mae: 0.1254 - val_loss: 0.0320 - val_mae: 0.1307 - 49ms/epoch - 12ms/step
# Epoch 108/200
# 4/4 - 0s - loss: 0.0293 - mae: 0.1261 - val_loss: 0.0305 - val_mae: 0.1292 - 44ms/epoch - 11ms/step
# Epoch 109/200
# 4/4 - 0s - loss: 0.0292 - mae: 0.1261 - val_loss: 0.0325 - val_mae: 0.1313 - 46ms/epoch - 11ms/step
# Epoch 110/200
# 4/4 - 0s - loss: 0.0283 - mae: 0.1244 - val_loss: 0.0334 - val_mae: 0.1333 - 65ms/epoch - 16ms/step
# Epoch 111/200
# 4/4 - 0s - loss: 0.0289 - mae: 0.1248 - val_loss: 0.0337 - val_mae: 0.1334 - 44ms/epoch - 11ms/step
# Epoch 112/200
# 4/4 - 0s - loss: 0.0286 - mae: 0.1245 - val_loss: 0.0337 - val_mae: 0.1345 - 43ms/epoch - 11ms/step
# Epoch 113/200
# 4/4 - 0s - loss: 0.0284 - mae: 0.1240 - val_loss: 0.0316 - val_mae: 0.1298 - 46ms/epoch - 11ms/step
# Epoch 114/200
# 4/4 - 0s - loss: 0.0282 - mae: 0.1240 - val_loss: 0.0304 - val_mae: 0.1285 - 44ms/epoch - 11ms/step
# Epoch 115/200
# 4/4 - 0s - loss: 0.0282 - mae: 0.1241 - val_loss: 0.0315 - val_mae: 0.1302 - 40ms/epoch - 10ms/step
# Epoch 116/200
# 4/4 - 0s - loss: 0.0283 - mae: 0.1247 - val_loss: 0.0308 - val_mae: 0.1301 - 43ms/epoch - 11ms/step
# Epoch 117/200
# 4/4 - 0s - loss: 0.0284 - mae: 0.1254 - val_loss: 0.0320 - val_mae: 0.1298 - 48ms/epoch - 12ms/step
# Epoch 118/200
# 4/4 - 0s - loss: 0.0289 - mae: 0.1247 - val_loss: 0.0323 - val_mae: 0.1322 - 44ms/epoch - 11ms/step
# Epoch 119/200
# 4/4 - 0s - loss: 0.0284 - mae: 0.1241 - val_loss: 0.0345 - val_mae: 0.1367 - 51ms/epoch - 13ms/step
# Epoch 120/200
# 4/4 - 0s - loss: 0.0284 - mae: 0.1240 - val_loss: 0.0337 - val_mae: 0.1342 - 40ms/epoch - 10ms/step
# Epoch 121/200
# 4/4 - 0s - loss: 0.0283 - mae: 0.1237 - val_loss: 0.0303 - val_mae: 0.1274 - 93ms/epoch - 23ms/step
# Epoch 122/200
# 4/4 - 0s - loss: 0.0285 - mae: 0.1249 - val_loss: 0.0309 - val_mae: 0.1285 - 58ms/epoch - 14ms/step
# Epoch 123/200
# 4/4 - 0s - loss: 0.0285 - mae: 0.1257 - val_loss: 0.0321 - val_mae: 0.1320 - 66ms/epoch - 17ms/step
# Epoch 124/200
# 4/4 - 0s - loss: 0.0282 - mae: 0.1238 - val_loss: 0.0329 - val_mae: 0.1328 - 51ms/epoch - 13ms/step
# Epoch 125/200
# 4/4 - 0s - loss: 0.0279 - mae: 0.1239 - val_loss: 0.0313 - val_mae: 0.1300 - 66ms/epoch - 16ms/step
# Epoch 126/200
# 4/4 - 0s - loss: 0.0284 - mae: 0.1246 - val_loss: 0.0310 - val_mae: 0.1303 - 50ms/epoch - 12ms/step
# Epoch 127/200
# 4/4 - 0s - loss: 0.0284 - mae: 0.1250 - val_loss: 0.0317 - val_mae: 0.1306 - 57ms/epoch - 14ms/step
# Epoch 128/200
# 4/4 - 0s - loss: 0.0279 - mae: 0.1240 - val_loss: 0.0314 - val_mae: 0.1302 - 68ms/epoch - 17ms/step
# Epoch 129/200
# 4/4 - 0s - loss: 0.0278 - mae: 0.1238 - val_loss: 0.0312 - val_mae: 0.1301 - 82ms/epoch - 20ms/step
# Epoch 130/200
# 4/4 - 0s - loss: 0.0280 - mae: 0.1246 - val_loss: 0.0323 - val_mae: 0.1322 - 67ms/epoch - 17ms/step
# Epoch 131/200
# 4/4 - 0s - loss: 0.0282 - mae: 0.1247 - val_loss: 0.0327 - val_mae: 0.1330 - 58ms/epoch - 14ms/step
# Epoch 132/200
# 4/4 - 0s - loss: 0.0281 - mae: 0.1239 - val_loss: 0.0307 - val_mae: 0.1296 - 54ms/epoch - 13ms/step
# Epoch 133/200
# 4/4 - 0s - loss: 0.0275 - mae: 0.1233 - val_loss: 0.0318 - val_mae: 0.1316 - 72ms/epoch - 18ms/step
# Epoch 134/200
# 4/4 - 0s - loss: 0.0279 - mae: 0.1244 - val_loss: 0.0335 - val_mae: 0.1356 - 103ms/epoch - 26ms/step
# Epoch 135/200
# 4/4 - 0s - loss: 0.0281 - mae: 0.1238 - val_loss: 0.0334 - val_mae: 0.1338 - 97ms/epoch - 24ms/step
# Epoch 136/200
# 4/4 - 0s - loss: 0.0283 - mae: 0.1232 - val_loss: 0.0338 - val_mae: 0.1356 - 77ms/epoch - 19ms/step
# Epoch 137/200
# 4/4 - 0s - loss: 0.0279 - mae: 0.1233 - val_loss: 0.0311 - val_mae: 0.1303 - 59ms/epoch - 15ms/step
# Epoch 138/200
# 4/4 - 0s - loss: 0.0278 - mae: 0.1234 - val_loss: 0.0349 - val_mae: 0.1364 - 81ms/epoch - 20ms/step
# Epoch 139/200
# 4/4 - 0s - loss: 0.0276 - mae: 0.1229 - val_loss: 0.0324 - val_mae: 0.1333 - 82ms/epoch - 20ms/step
# Epoch 140/200
# 4/4 - 0s - loss: 0.0273 - mae: 0.1225 - val_loss: 0.0395 - val_mae: 0.1470 - 47ms/epoch - 12ms/step
# Epoch 141/200
# 4/4 - 0s - loss: 0.0282 - mae: 0.1230 - val_loss: 0.0336 - val_mae: 0.1350 - 58ms/epoch - 15ms/step
# Epoch 142/200
# 4/4 - 0s - loss: 0.0275 - mae: 0.1227 - val_loss: 0.0371 - val_mae: 0.1411 - 71ms/epoch - 18ms/step
# Epoch 143/200
# 4/4 - 0s - loss: 0.0280 - mae: 0.1235 - val_loss: 0.0317 - val_mae: 0.1317 - 62ms/epoch - 15ms/step
# Epoch 144/200
# 4/4 - 0s - loss: 0.0277 - mae: 0.1232 - val_loss: 0.0328 - val_mae: 0.1341 - 45ms/epoch - 11ms/step
# Epoch 145/200
# 4/4 - 0s - loss: 0.0278 - mae: 0.1222 - val_loss: 0.0355 - val_mae: 0.1383 - 87ms/epoch - 22ms/step
# Epoch 146/200
# 4/4 - 0s - loss: 0.0274 - mae: 0.1220 - val_loss: 0.0315 - val_mae: 0.1301 - 76ms/epoch - 19ms/step
# Epoch 147/200
# 4/4 - 0s - loss: 0.0275 - mae: 0.1229 - val_loss: 0.0348 - val_mae: 0.1375 - 77ms/epoch - 19ms/step
# Epoch 148/200
# 4/4 - 0s - loss: 0.0277 - mae: 0.1225 - val_loss: 0.0350 - val_mae: 0.1379 - 57ms/epoch - 14ms/step
# Epoch 149/200
# 4/4 - 0s - loss: 0.0269 - mae: 0.1211 - val_loss: 0.0316 - val_mae: 0.1310 - 59ms/epoch - 15ms/step
# Epoch 150/200
# 4/4 - 0s - loss: 0.0275 - mae: 0.1229 - val_loss: 0.0342 - val_mae: 0.1357 - 52ms/epoch - 13ms/step
# Epoch 151/200
# 4/4 - 0s - loss: 0.0272 - mae: 0.1222 - val_loss: 0.0318 - val_mae: 0.1315 - 53ms/epoch - 13ms/step
# Epoch 152/200
# 4/4 - 0s - loss: 0.0279 - mae: 0.1236 - val_loss: 0.0330 - val_mae: 0.1328 - 59ms/epoch - 15ms/step
# Epoch 153/200
# 4/4 - 0s - loss: 0.0273 - mae: 0.1220 - val_loss: 0.0384 - val_mae: 0.1447 - 51ms/epoch - 13ms/step
# Epoch 154/200
# 4/4 - 0s - loss: 0.0273 - mae: 0.1215 - val_loss: 0.0350 - val_mae: 0.1382 - 45ms/epoch - 11ms/step
# Epoch 155/200
# 4/4 - 0s - loss: 0.0270 - mae: 0.1213 - val_loss: 0.0342 - val_mae: 0.1358 - 72ms/epoch - 18ms/step
# Epoch 156/200
# 4/4 - 0s - loss: 0.0269 - mae: 0.1216 - val_loss: 0.0387 - val_mae: 0.1461 - 70ms/epoch - 18ms/step
# Epoch 157/200
# 4/4 - 0s - loss: 0.0277 - mae: 0.1223 - val_loss: 0.0325 - val_mae: 0.1319 - 56ms/epoch - 14ms/step
# Epoch 158/200
# 4/4 - 0s - loss: 0.0275 - mae: 0.1227 - val_loss: 0.0340 - val_mae: 0.1358 - 42ms/epoch - 10ms/step
# Epoch 159/200
# 4/4 - 0s - loss: 0.0267 - mae: 0.1206 - val_loss: 0.0384 - val_mae: 0.1456 - 54ms/epoch - 13ms/step
# Epoch 160/200
# 4/4 - 0s - loss: 0.0273 - mae: 0.1220 - val_loss: 0.0385 - val_mae: 0.1450 - 44ms/epoch - 11ms/step
# Epoch 161/200
# 4/4 - 0s - loss: 0.0276 - mae: 0.1223 - val_loss: 0.0324 - val_mae: 0.1324 - 48ms/epoch - 12ms/step
# Epoch 162/200
# 4/4 - 0s - loss: 0.0277 - mae: 0.1230 - val_loss: 0.0344 - val_mae: 0.1372 - 47ms/epoch - 12ms/step
# Epoch 163/200
# 4/4 - 0s - loss: 0.0273 - mae: 0.1219 - val_loss: 0.0314 - val_mae: 0.1299 - 44ms/epoch - 11ms/step
# Epoch 164/200
# 4/4 - 0s - loss: 0.0271 - mae: 0.1228 - val_loss: 0.0374 - val_mae: 0.1417 - 50ms/epoch - 13ms/step
# Epoch 165/200
# 4/4 - 0s - loss: 0.0273 - mae: 0.1220 - val_loss: 0.0359 - val_mae: 0.1398 - 52ms/epoch - 13ms/step
# Epoch 166/200
# 4/4 - 0s - loss: 0.0274 - mae: 0.1217 - val_loss: 0.0344 - val_mae: 0.1364 - 62ms/epoch - 16ms/step
# Epoch 167/200
# 4/4 - 0s - loss: 0.0272 - mae: 0.1216 - val_loss: 0.0325 - val_mae: 0.1331 - 111ms/epoch - 28ms/step
# Epoch 168/200
# 4/4 - 0s - loss: 0.0272 - mae: 0.1223 - val_loss: 0.0361 - val_mae: 0.1408 - 51ms/epoch - 13ms/step
# Epoch 169/200
# 4/4 - 0s - loss: 0.0271 - mae: 0.1211 - val_loss: 0.0336 - val_mae: 0.1348 - 68ms/epoch - 17ms/step
# Epoch 170/200
# 4/4 - 0s - loss: 0.0270 - mae: 0.1214 - val_loss: 0.0324 - val_mae: 0.1329 - 35ms/epoch - 9ms/step
# Epoch 171/200
# 4/4 - 0s - loss: 0.0274 - mae: 0.1218 - val_loss: 0.0340 - val_mae: 0.1354 - 39ms/epoch - 10ms/step
# Epoch 172/200
# 4/4 - 0s - loss: 0.0268 - mae: 0.1207 - val_loss: 0.0361 - val_mae: 0.1399 - 30ms/epoch - 8ms/step
# Epoch 173/200
# 4/4 - 0s - loss: 0.0271 - mae: 0.1210 - val_loss: 0.0344 - val_mae: 0.1365 - 32ms/epoch - 8ms/step
# Epoch 174/200
# 4/4 - 0s - loss: 0.0268 - mae: 0.1207 - val_loss: 0.0364 - val_mae: 0.1415 - 31ms/epoch - 8ms/step
# Epoch 175/200
# 4/4 - 0s - loss: 0.0274 - mae: 0.1217 - val_loss: 0.0379 - val_mae: 0.1444 - 39ms/epoch - 10ms/step
# Epoch 176/200
# 4/4 - 0s - loss: 0.0267 - mae: 0.1204 - val_loss: 0.0346 - val_mae: 0.1388 - 30ms/epoch - 8ms/step
# Epoch 177/200
# 4/4 - 0s - loss: 0.0265 - mae: 0.1201 - val_loss: 0.0380 - val_mae: 0.1440 - 32ms/epoch - 8ms/step
# Epoch 178/200
# 4/4 - 0s - loss: 0.0272 - mae: 0.1210 - val_loss: 0.0328 - val_mae: 0.1333 - 33ms/epoch - 8ms/step
# Epoch 179/200
# 4/4 - 0s - loss: 0.0267 - mae: 0.1218 - val_loss: 0.0354 - val_mae: 0.1386 - 38ms/epoch - 10ms/step
# Epoch 180/200
# 4/4 - 0s - loss: 0.0267 - mae: 0.1203 - val_loss: 0.0355 - val_mae: 0.1384 - 29ms/epoch - 7ms/step
# Epoch 181/200
# 4/4 - 0s - loss: 0.0273 - mae: 0.1209 - val_loss: 0.0410 - val_mae: 0.1509 - 34ms/epoch - 8ms/step
# Epoch 182/200
# 4/4 - 0s - loss: 0.0269 - mae: 0.1194 - val_loss: 0.0352 - val_mae: 0.1382 - 34ms/epoch - 9ms/step
# Epoch 183/200
# 4/4 - 0s - loss: 0.0266 - mae: 0.1205 - val_loss: 0.0365 - val_mae: 0.1412 - 34ms/epoch - 9ms/step
# Epoch 184/200
# 4/4 - 0s - loss: 0.0264 - mae: 0.1197 - val_loss: 0.0319 - val_mae: 0.1317 - 34ms/epoch - 8ms/step
# Epoch 185/200
# 4/4 - 0s - loss: 0.0271 - mae: 0.1216 - val_loss: 0.0344 - val_mae: 0.1370 - 31ms/epoch - 8ms/step
# Epoch 186/200
# 4/4 - 0s - loss: 0.0266 - mae: 0.1204 - val_loss: 0.0340 - val_mae: 0.1355 - 29ms/epoch - 7ms/step
# Epoch 187/200
# 4/4 - 0s - loss: 0.0269 - mae: 0.1215 - val_loss: 0.0361 - val_mae: 0.1412 - 30ms/epoch - 8ms/step
# Epoch 188/200
# 4/4 - 0s - loss: 0.0266 - mae: 0.1207 - val_loss: 0.0337 - val_mae: 0.1362 - 30ms/epoch - 8ms/step
# Epoch 189/200
# 4/4 - 0s - loss: 0.0270 - mae: 0.1215 - val_loss: 0.0346 - val_mae: 0.1368 - 29ms/epoch - 7ms/step
# Epoch 190/200
# 4/4 - 0s - loss: 0.0269 - mae: 0.1201 - val_loss: 0.0350 - val_mae: 0.1384 - 32ms/epoch - 8ms/step
# Epoch 191/200
# 4/4 - 0s - loss: 0.0262 - mae: 0.1196 - val_loss: 0.0361 - val_mae: 0.1401 - 37ms/epoch - 9ms/step
# Epoch 192/200
# 4/4 - 0s - loss: 0.0268 - mae: 0.1206 - val_loss: 0.0327 - val_mae: 0.1344 - 31ms/epoch - 8ms/step
# Epoch 193/200
# 4/4 - 0s - loss: 0.0269 - mae: 0.1220 - val_loss: 0.0356 - val_mae: 0.1397 - 30ms/epoch - 7ms/step
# Epoch 194/200
# 4/4 - 0s - loss: 0.0268 - mae: 0.1207 - val_loss: 0.0341 - val_mae: 0.1372 - 31ms/epoch - 8ms/step
# Epoch 195/200
# 4/4 - 0s - loss: 0.0264 - mae: 0.1206 - val_loss: 0.0368 - val_mae: 0.1416 - 32ms/epoch - 8ms/step
# Epoch 196/200
# 4/4 - 0s - loss: 0.0263 - mae: 0.1188 - val_loss: 0.0387 - val_mae: 0.1457 - 31ms/epoch - 8ms/step
# Epoch 197/200
# 4/4 - 0s - loss: 0.0267 - mae: 0.1200 - val_loss: 0.0357 - val_mae: 0.1397 - 41ms/epoch - 10ms/step
# Epoch 198/200
# 4/4 - 0s - loss: 0.0266 - mae: 0.1196 - val_loss: 0.0413 - val_mae: 0.1515 - 36ms/epoch - 9ms/step
# Epoch 199/200
# 4/4 - 0s - loss: 0.0264 - mae: 0.1199 - val_loss: 0.0347 - val_mae: 0.1371 - 37ms/epoch - 9ms/step
# Epoch 200/200
# 4/4 - 0s - loss: 0.0267 - mae: 0.1211 - val_loss: 0.0366 - val_mae: 0.1419 - 32ms/epoch - 8ms/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 72
#
#  dense_1 (Dense)             (None, 8)                 72
#
#  stochastic_dropout (Stochas  (None, 8)                0
#  ticDropout)
#
#  dense_2 (Dense)             (None, 8)                 72
#
#  stochastic_dropout_1 (Stoch  (None, 8)                0
#  asticDropout)
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________
# intermediate samples shape  (10, 3000, 1)
# pred_samples shape  (10, 3000, 1)
# pred_mean shape  (3000, 1)
# pred_std shape  (3000, 1)
# prediction mean :
#  [[0.588427  ]
#  [0.26784137]
#  [0.37757683]
#  ...
#  [0.26649147]
#  [0.25800687]
#  [0.74503577]]
# prediction mean shape  (3000, 1)
# prediction std :
#  [[0.06699116]
#  [0.04312246]
#  [0.04901423]
#  ...
#  [0.02246398]
#  [0.03595688]
#  [0.11906374]]
# prediction std shape  (3000, 1)
# prediction samples :
#  [[[0.6839777 ]
#   [0.30287382]
#   [0.2999536 ]
#   ...
#   [0.25900713]
#   [0.30287382]
#   [0.7223904 ]]
#
#  [[0.57794476]
#   [0.35158846]
#   [0.3921103 ]
#   ...
#   [0.26394922]
#   [0.21092117]
#   [0.805022  ]]
#
#  [[0.6583842 ]
#   [0.31439915]
#   [0.40865174]
#   ...
#   [0.26394922]
#   [0.21092117]
#   [0.70142186]]
#
#  ...
#
#  [[0.4958195 ]
#   [0.22591406]
#   [0.39104635]
#   ...
#   [0.26394922]
#   [0.23483577]
#   [0.6776521 ]]
#
#  [[0.61246604]
#   [0.24468397]
#   [0.4486863 ]
#   ...
#   [0.2733087 ]
#   [0.23483577]
#   [0.9460435 ]]
#
#  [[0.64341897]
#   [0.30287382]
#   [0.32873574]
#   ...
#   [0.22071628]
#   [0.28102204]
#   [0.8170235 ]]]
# prediction samples shape  (10, 3000, 1)

# %% [markdown]
# ## Ground Truth vs prediction plot

# %%
# Analysis of the input
#num_of_samples_to_be_explained = 1
#start_index = np.random.randint(0, test_data.shape[0])
#print('start_index : ', start_index)

#test_input = test_data[start_index:start_index+num_of_samples_to_be_explained]
#print('test_input shape :', test_input.shape)

#test_input_adj = np.expand_dims(test_input, axis=-1)
#print('test_input_adj shape :', test_input_adj.shape)

pred_samples, pred_mean, pred_std = stochastic_model.predict_output(test_data, num_samples=num_samples)
print('pred samples shape ', pred_samples.shape)
print('pred mean shape ', pred_mean.shape)
print('pred std shape ', pred_std.shape)

print('pred samples : \n ', pred_samples)
print('pred mean : \n ', pred_mean)
print('pred std : \n ', pred_std)
# Out:
# intermediate samples shape  (10, 3000, 1)
# pred samples shape  (10, 3000, 1)
# pred mean shape  (3000, 1)
# pred std shape  (3000, 1)
# pred samples :
#   [[[0.40235043]
#   [0.3445527 ]
#   [0.34616584]
#   ...
#   [0.22777295]
#   [0.37590772]
#   [0.69392705]]
#
#  [[0.7440684 ]
#   [0.2935522 ]
#   [0.4194384 ]
#   ...
#   [0.25900713]
#   [0.41299906]
#   [0.3080762 ]]
#
#  [[0.5477604 ]
#   [0.30287382]
#   [0.37829518]
#   ...
#   [0.22777295]
#   [0.21092117]
#   [0.90986586]]
#
#  ...
#
#  [[0.5406651 ]
#   [0.32181463]
#   [0.45187438]
#   ...
#   [0.26394922]
#   [0.30287382]
#   [0.79872745]]
#
#  [[0.7074999 ]
#   [0.30478114]
#   [0.41372737]
#   ...
#   [0.26394922]
#   [0.21092117]
#   [0.7967547 ]]
#
#  [[0.5822674 ]
#   [0.26667705]
#   [0.42233214]
#   ...
#   [0.22071628]
#   [0.27330506]
#   [0.74678147]]]
# pred mean :
#   [[0.56645155]
#  [0.2758888 ]
#  [0.40890273]
#  ...
#  [0.25925055]
#  [0.2899925 ]
#  [0.7201049 ]]
# pred std :
#   [[0.10016964]
#  [0.04110786]
#  [0.03594293]
#  ...
#  [0.03271795]
#  [0.07394881]
#  [0.16706194]]

# %%
start_index = np.random.randint(test_data.shape[0]-150)
#random = range(start_index, start_index+100)
random = range(0, 100)
print('indices to be plotted \n', random)
test_labels_plot= np.asarray([float(test_labels[i]) for i in random])
mean_plot = np.asarray([float(pred_mean[i]) for i in random])
std_plot = np.asarray([float(pred_std[i]) for i in random])

plot_gt_vs_pred(test_labels_plot, mean_plot, std_plot, path+'output_plots/'+uncert_name+'_gt_vs_prediction', random, uncert_name)
# Out:
# indices to be plotted
#  range(0, 100)

# %%
'''
##TOY CODE to test the plotting of custom horizontal bar chart 
#reference for this code below : 
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/barh.htmlimport matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)

plt.figure(figsize=(25,10))
plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ['Tom', 'Dick', 'Harry', 'Slim', 'Jim']
y_pos = np.arange(1, len(people)+1)

error = np.random.rand(len(people))
performance = 3 + 10 * error

print(y_pos)
print(people)
print(performance)
print(error)


a = ax.barh(y_pos, performance, xerr=error, align='center', label='performance')

for i in range(len(a)):
    print(a[i])

ax.set_yticks([1, 2, 3, 4, 5])
ax.set_yticklabels(labels=['Tom', 'Dick', 'Harry', 'Slim', 'Jim'])

labels = ['performance', 'error']
colors = ['C0', 'k']
legend_colors = list(set(colors))
print(legend_colors)

error = plt.plot([], label='error', linestyle='-', color='k')
performance = plt.Rectangle((0,0),1,1, color='C0')

# Create a legend for the first line.
first_legend = plt.legend(handles=error)

# Add the legend manually to the current Axes. (https://matplotlib.org/2.0.2/users/legend_guide.html)

#ax.invert_yaxis()  # labels read top-to-bottom  
ax.set_xlabel('Performance') 
ax.set_title('How fast do you want to go today?')
plt.grid(alpha=0.2)
plt.legend()
plt.show()


#reference for generating a custom legend 
# https://matplotlib.org/2.0.2/users/legend_guide.html
'''
# Out:
# "\n##TOY CODE to test the plotting of custom horizontal bar chart \n#reference for this code below : \n# https://matplotlib.org/stable/gallery/lines_bars_and_markers/barh.htmlimport matplotlib.pyplot as plt\nimport numpy as np\n\n# Fixing random state for reproducibility\nnp.random.seed(19680801)\n\nplt.figure(figsize=(25,10))\nplt.rcdefaults()\nfig, ax = plt.subplots()\n\n# Example data\npeople = ['Tom', 'Dick', 'Harry', 'Slim', 'Jim']\ny_pos = np.arange(1, len(people)+1)\n\nerror = np.random.rand(len(people))\nperformance = 3 + 10 * error\n\nprint(y_pos)\nprint(people)\nprint(performance)\nprint(error)\n\n\na = ax.barh(y_pos, performance, xerr=error, align='center', label='performance')\n\nfor i in range(len(a)):\n    print(a[i])\n\nax.set_yticks([1, 2, 3, 4, 5])\nax.set_yticklabels(labels=['Tom', 'Dick', 'Harry', 'Slim', 'Jim'])\n\nlabels = ['performance', 'error']\ncolors = ['C0', 'k']\nlegend_colors = list(set(colors))\nprint(legend_colors)\n\nerror = plt.plot([], label='error', linestyle='-', color='k')\nperformance = plt.Rectangle((0,0),1,1, color='C0')\n\n# Create a legend for the first line.\nfirst_legend = plt.legend(handles=error)\n\n# Add the legend manually to the current Axes. (https://matplotlib.org/2.0.2/users/legend_guide.html)\n\n#ax.invert_yaxis()  # labels read top-to-bottom  \nax.set_xlabel('Performance') \nax.set_title('How fast do you want to go today?')\nplt.grid(alpha=0.2)\nplt.legend()\nplt.show()\n\n\n#reference for generating a custom legend \n# https://matplotlib.org/2.0.2/users/legend_guide.html\n"
