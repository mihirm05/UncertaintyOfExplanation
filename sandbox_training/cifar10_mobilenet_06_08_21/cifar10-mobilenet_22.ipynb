# %%
# dataset = cifar10
# model = mobilenet
# optimizer = ADAM (0.001)
# loss = categorical_crossentropy
# batch_size = 32
# decay = l2 (0.01)
# augmentation = off
# validation_split = 0.2

# %%
import tensorflow as tf
import os

from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, Dropout
from tensorflow.keras.layers import Input, Flatten, AveragePooling2D, Add
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, SGD
# https://towardsdatascience.com/weight-decay-l2-regularization-90a9e17713cd
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import L2

from tensorflow.keras.datasets import cifar10
from tensorflow.keras.datasets import fashion_mnist

# %%
batch_size=32
epochs=100
num_classes=10 
depth=20

# %%
model_type = 'MobileNet%d' % (depth)

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train/255
x_test = x_test/255

y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
input_shape=x_train.shape[1:]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
#datagen = ImageDataGenerator(rotation_range=40, horizontal_flip=True, zoom_range=0.1, width_shift_range=0.05, height_shift_range=0.05)
#augmented_data = datagen.flow(x_train[:40000], y_train[:40000])

# %%
def mobilenet(input_size, l2_decay, N_CLASSES):
    """
    Builds the MobileNet model.
    :param tuple input_size: The height and width (in that order) of the
        model input.
    :param float l2_decay: The amount of L2 weight decay to add to the
        loss. Applies only to kernels, not biases.
    :return tensorflow.keras.Sequential: A MobileNet model.
    """

    model = Sequential()

    def _add_bn_relu():
        model.add(BatchNormalization(scale=False))
        model.add(ReLU())

    def _add_depthwise_block(strides=1):
        model.add(DepthwiseConv2D(
            (3, 3),
            strides=strides,
            padding='same',
            kernel_regularizer=L2(l2=l2_decay)))
        _add_bn_relu()

    def _add_pointwise_block(filters):
        model.add(Conv2D(filters, (1, 1), kernel_regularizer=L2(l2=l2_decay)))
        _add_bn_relu()

    model.add(Conv2D(
        32, (3, 3),
        strides=2,
        padding='same',
        kernel_regularizer=L2(l2=l2_decay),
        input_shape=input_size + (3,)))
    _add_bn_relu()
    _add_depthwise_block()
    _add_pointwise_block(64)

    _add_depthwise_block(strides=2)
    _add_pointwise_block(128)
    _add_depthwise_block()
    _add_pointwise_block(128)

    _add_depthwise_block(strides=2)
    _add_pointwise_block(256)
    _add_depthwise_block()
    _add_pointwise_block(256)

    _add_depthwise_block(strides=2)
    _add_pointwise_block(512)
    for _ in range(5):
        _add_depthwise_block()
        _add_pointwise_block(512)

    _add_depthwise_block(strides=2)
    _add_pointwise_block(1024)
    _add_depthwise_block()
    _add_pointwise_block(1024)
    # model.add(Dropout(0.5))

    model.add(AveragePooling2D(pool_size=(input_size[0] // 32, input_size[1] // 32)))

    model.add(Flatten())
    model.add(Dense(N_CLASSES, kernel_regularizer=L2(l2=l2_decay)))
    model.add(Softmax())

    return model


model = mobilenet(input_size=(32, 32), l2_decay=0.01, N_CLASSES=10)
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 16, 16, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 16, 32)        96
# _________________________________________________________________
# re_lu (ReLU)                 (None, 16, 16, 32)        0
# _________________________________________________________________
# depthwise_conv2d (DepthwiseC (None, 16, 16, 32)        320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 32)        96
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        2112
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        192
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 16, 16, 64)        0
# _________________________________________________________________
# depthwise_conv2d_1 (Depthwis (None, 8, 8, 64)          640
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 64)          192
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 128)         8320
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         384
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 8, 8, 128)         0
# _________________________________________________________________
# depthwise_conv2d_2 (Depthwis (None, 8, 8, 128)         1280
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         384
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         16512
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 128)         384
# _________________________________________________________________
# re_lu_6 (ReLU)               (None, 8, 8, 128)         0
# _________________________________________________________________
# depthwise_conv2d_3 (Depthwis (None, 4, 4, 128)         1280
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 4, 128)         384
# _________________________________________________________________
# re_lu_7 (ReLU)               (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 256)         33024
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 4, 4, 256)         768
# _________________________________________________________________
# re_lu_8 (ReLU)               (None, 4, 4, 256)         0
# _________________________________________________________________
# depthwise_conv2d_4 (Depthwis (None, 4, 4, 256)         2560
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 4, 4, 256)         768
# _________________________________________________________________
# re_lu_9 (ReLU)               (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 256)         65792
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 4, 4, 256)         768
# _________________________________________________________________
# re_lu_10 (ReLU)              (None, 4, 4, 256)         0
# _________________________________________________________________
# depthwise_conv2d_5 (Depthwis (None, 2, 2, 256)         2560
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 2, 2, 256)         768
# _________________________________________________________________
# re_lu_11 (ReLU)              (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 2, 2, 512)         131584
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 2, 2, 512)         1536
# _________________________________________________________________
# re_lu_12 (ReLU)              (None, 2, 2, 512)         0
# _________________________________________________________________
# depthwise_conv2d_6 (Depthwis (None, 2, 2, 512)         5120
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 2, 2, 512)         1536
# _________________________________________________________________
# re_lu_13 (ReLU)              (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 2, 2, 512)         262656
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 2, 2, 512)         1536
# _________________________________________________________________
# re_lu_14 (ReLU)              (None, 2, 2, 512)         0
# _________________________________________________________________
# depthwise_conv2d_7 (Depthwis (None, 2, 2, 512)         5120
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 2, 2, 512)         1536
# _________________________________________________________________
# re_lu_15 (ReLU)              (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 512)         262656
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 2, 2, 512)         1536
# _________________________________________________________________
# re_lu_16 (ReLU)              (None, 2, 2, 512)         0
# _________________________________________________________________
# depthwise_conv2d_8 (Depthwis (None, 2, 2, 512)         5120
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 2, 2, 512)         1536
# _________________________________________________________________
# re_lu_17 (ReLU)              (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 2, 2, 512)         262656
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 2, 2, 512)         1536
# _________________________________________________________________
# re_lu_18 (ReLU)              (None, 2, 2, 512)         0
# _________________________________________________________________
# depthwise_conv2d_9 (Depthwis (None, 2, 2, 512)         5120
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 2, 2, 512)         1536
# _________________________________________________________________
# re_lu_19 (ReLU)              (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 2, 2, 512)         262656
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 2, 2, 512)         1536
# _________________________________________________________________
# re_lu_20 (ReLU)              (None, 2, 2, 512)         0
# _________________________________________________________________
# depthwise_conv2d_10 (Depthwi (None, 2, 2, 512)         5120
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 2, 2, 512)         1536
# _________________________________________________________________
# re_lu_21 (ReLU)              (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 2, 2, 512)         262656
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 2, 2, 512)         1536
# _________________________________________________________________
# re_lu_22 (ReLU)              (None, 2, 2, 512)         0
# _________________________________________________________________
# depthwise_conv2d_11 (Depthwi (None, 1, 1, 512)         5120
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 1, 1, 512)         1536
# _________________________________________________________________
# re_lu_23 (ReLU)              (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 1, 1, 1024)        525312
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 1, 1, 1024)        3072
# _________________________________________________________________
# re_lu_24 (ReLU)              (None, 1, 1, 1024)        0
# _________________________________________________________________
# depthwise_conv2d_12 (Depthwi (None, 1, 1, 1024)        10240
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 1, 1, 1024)        3072
# _________________________________________________________________
# re_lu_25 (ReLU)              (None, 1, 1, 1024)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 1, 1024)        1049600
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 1, 1, 1024)        3072
# _________________________________________________________________
# re_lu_26 (ReLU)              (None, 1, 1, 1024)        0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 1, 1, 1024)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                10250
# _________________________________________________________________
# softmax (Softmax)            (None, 10)                0
# =================================================================
# Total params: 3,239,114
# Trainable params: 3,217,226
# Non-trainable params: 21,888
# _________________________________________________________________
# None

# %%
#model_tf = tf.keras.applications.mobilenet.MobileNet(input_shape=(32, 32, 3), weights=None, classes=10)
#print(model_tf.summary())

# %%
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# %%
#steps = int(x_train.shape[0]/batch_size) 

history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/100
# 1250/1250 [==============================] - 26s 14ms/step - loss: 27.3341 - accuracy: 0.2018 - val_loss: 4.7091 - val_accuracy: 0.2871
# Epoch 2/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 3.9439 - accuracy: 0.2941 - val_loss: 2.7207 - val_accuracy: 0.3211
# Epoch 3/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 2.4444 - accuracy: 0.3645 - val_loss: 2.3386 - val_accuracy: 0.3375
# Epoch 4/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 2.0827 - accuracy: 0.4256 - val_loss: 2.3769 - val_accuracy: 0.3141
# Epoch 5/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.9439 - accuracy: 0.4638 - val_loss: 2.1089 - val_accuracy: 0.4176
# Epoch 6/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.8942 - accuracy: 0.5129 - val_loss: 2.0599 - val_accuracy: 0.4270
# Epoch 7/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.7868 - accuracy: 0.5568 - val_loss: 2.3208 - val_accuracy: 0.4254
# Epoch 8/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.7445 - accuracy: 0.5728 - val_loss: 1.8991 - val_accuracy: 0.4968
# Epoch 9/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.6721 - accuracy: 0.5946 - val_loss: 2.5336 - val_accuracy: 0.3332
# Epoch 10/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.6099 - accuracy: 0.6163 - val_loss: 1.8521 - val_accuracy: 0.5023
# Epoch 11/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.5576 - accuracy: 0.6259 - val_loss: 1.8665 - val_accuracy: 0.5207
# Epoch 12/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.5329 - accuracy: 0.6376 - val_loss: 2.1989 - val_accuracy: 0.4419
# Epoch 13/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.4945 - accuracy: 0.6489 - val_loss: 2.1811 - val_accuracy: 0.3987
# Epoch 14/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.4486 - accuracy: 0.6562 - val_loss: 9.9069 - val_accuracy: 0.0989
# Epoch 15/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.4633 - accuracy: 0.6561 - val_loss: 1.8567 - val_accuracy: 0.4951
# Epoch 16/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.4135 - accuracy: 0.6708 - val_loss: 1.6252 - val_accuracy: 0.5520
# Epoch 17/100
# 1250/1250 [==============================] - 17s 14ms/step - loss: 1.3842 - accuracy: 0.6804 - val_loss: 2.3386 - val_accuracy: 0.3137
# Epoch 18/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.3646 - accuracy: 0.6807 - val_loss: 2.8344 - val_accuracy: 0.2324
# Epoch 19/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.3408 - accuracy: 0.6862 - val_loss: 2.9365 - val_accuracy: 0.2132
# Epoch 20/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.3206 - accuracy: 0.6910 - val_loss: 1.8064 - val_accuracy: 0.4952
# Epoch 21/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.3234 - accuracy: 0.6878 - val_loss: 3.2364 - val_accuracy: 0.2817
# Epoch 22/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.2990 - accuracy: 0.6929 - val_loss: 2.1066 - val_accuracy: 0.3428
# Epoch 23/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.2884 - accuracy: 0.6970 - val_loss: 3.9200 - val_accuracy: 0.1304
# Epoch 24/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.2526 - accuracy: 0.7052 - val_loss: 3.1373 - val_accuracy: 0.3172
# Epoch 25/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.2532 - accuracy: 0.7031 - val_loss: 3.9480 - val_accuracy: 0.2644
# Epoch 26/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.2561 - accuracy: 0.7012 - val_loss: 3.8233 - val_accuracy: 0.1918
# Epoch 27/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.2158 - accuracy: 0.7136 - val_loss: 3.4727 - val_accuracy: 0.3356
# Epoch 28/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.2138 - accuracy: 0.7138 - val_loss: 3.3480 - val_accuracy: 0.2626
# Epoch 29/100
# 1250/1250 [==============================] - 17s 14ms/step - loss: 1.2026 - accuracy: 0.7134 - val_loss: 2.6800 - val_accuracy: 0.2192
# Epoch 30/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.2144 - accuracy: 0.7096 - val_loss: 6.8408 - val_accuracy: 0.1099
# Epoch 31/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.1788 - accuracy: 0.7176 - val_loss: 1.9572 - val_accuracy: 0.5193
# Epoch 32/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.1839 - accuracy: 0.7153 - val_loss: 3.5513 - val_accuracy: 0.1677
# Epoch 33/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.1800 - accuracy: 0.7174 - val_loss: 6.4104 - val_accuracy: 0.1560
# Epoch 34/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.1858 - accuracy: 0.7205 - val_loss: 3.9658 - val_accuracy: 0.1788
# Epoch 35/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.1647 - accuracy: 0.7237 - val_loss: 3.0384 - val_accuracy: 0.3291
# Epoch 36/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.1515 - accuracy: 0.7253 - val_loss: 3.1193 - val_accuracy: 0.2409
# Epoch 37/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.1507 - accuracy: 0.7236 - val_loss: 3.9082 - val_accuracy: 0.2132
# Epoch 38/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.1616 - accuracy: 0.7276 - val_loss: 5.5840 - val_accuracy: 0.1764
# Epoch 39/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.1512 - accuracy: 0.7291 - val_loss: 2.7475 - val_accuracy: 0.2517
# Epoch 40/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.1421 - accuracy: 0.7266 - val_loss: 7.5283 - val_accuracy: 0.1616
# Epoch 41/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.1362 - accuracy: 0.7269 - val_loss: 6.0746 - val_accuracy: 0.1750
# Epoch 42/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.1342 - accuracy: 0.7274 - val_loss: 3.9450 - val_accuracy: 0.1827
# Epoch 43/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.1180 - accuracy: 0.7333 - val_loss: 2.9013 - val_accuracy: 0.2516
# Epoch 44/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.1205 - accuracy: 0.7335 - val_loss: 3.8058 - val_accuracy: 0.2461
# Epoch 45/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.1167 - accuracy: 0.7379 - val_loss: 4.9858 - val_accuracy: 0.2367
# Epoch 46/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0955 - accuracy: 0.7357 - val_loss: 2.6176 - val_accuracy: 0.2554
# Epoch 47/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.0970 - accuracy: 0.7378 - val_loss: 4.3706 - val_accuracy: 0.2344
# Epoch 48/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.1253 - accuracy: 0.7320 - val_loss: 3.8446 - val_accuracy: 0.2735
# Epoch 49/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.1018 - accuracy: 0.7335 - val_loss: 1.8430 - val_accuracy: 0.4401
# Epoch 50/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0998 - accuracy: 0.7397 - val_loss: 6.3042 - val_accuracy: 0.1233
# Epoch 51/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.0973 - accuracy: 0.7364 - val_loss: 7.1897 - val_accuracy: 0.1580
# Epoch 52/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0824 - accuracy: 0.7390 - val_loss: 8.0663 - val_accuracy: 0.1529
# Epoch 53/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.0862 - accuracy: 0.7403 - val_loss: 6.1261 - val_accuracy: 0.1083
# Epoch 54/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0849 - accuracy: 0.7386 - val_loss: 4.5152 - val_accuracy: 0.1621
# Epoch 55/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0903 - accuracy: 0.7372 - val_loss: 2.3096 - val_accuracy: 0.3227
# Epoch 56/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0828 - accuracy: 0.7447 - val_loss: 4.8164 - val_accuracy: 0.1802
# Epoch 57/100
# 1250/1250 [==============================] - 17s 14ms/step - loss: 1.0780 - accuracy: 0.7399 - val_loss: 3.4631 - val_accuracy: 0.2439
# Epoch 58/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0707 - accuracy: 0.7415 - val_loss: 4.2674 - val_accuracy: 0.2357
# Epoch 59/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.0614 - accuracy: 0.7432 - val_loss: 4.8208 - val_accuracy: 0.2432
# Epoch 60/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0656 - accuracy: 0.7405 - val_loss: 11.9989 - val_accuracy: 0.0952
# Epoch 61/100
# 1250/1250 [==============================] - 17s 14ms/step - loss: 1.0819 - accuracy: 0.7372 - val_loss: 32.4333 - val_accuracy: 0.1014
# Epoch 62/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0669 - accuracy: 0.7433 - val_loss: 4.8750 - val_accuracy: 0.2020
# Epoch 63/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0609 - accuracy: 0.7473 - val_loss: 9.6740 - val_accuracy: 0.1278
# Epoch 64/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0821 - accuracy: 0.7421 - val_loss: 5.4996 - val_accuracy: 0.2045
# Epoch 65/100
# 1250/1250 [==============================] - 17s 14ms/step - loss: 1.0662 - accuracy: 0.7462 - val_loss: 5.0279 - val_accuracy: 0.2342
# Epoch 66/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0755 - accuracy: 0.7437 - val_loss: 7.9697 - val_accuracy: 0.1437
# Epoch 67/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0691 - accuracy: 0.7448 - val_loss: 5.8016 - val_accuracy: 0.2248
# Epoch 68/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0705 - accuracy: 0.7425 - val_loss: 6.9984 - val_accuracy: 0.1081
# Epoch 69/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.0514 - accuracy: 0.7470 - val_loss: 20.4622 - val_accuracy: 0.1025
# Epoch 70/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0557 - accuracy: 0.7448 - val_loss: 7.4203 - val_accuracy: 0.1173
# Epoch 71/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0421 - accuracy: 0.7483 - val_loss: 6.0288 - val_accuracy: 0.1562
# Epoch 72/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0538 - accuracy: 0.7458 - val_loss: 3.4728 - val_accuracy: 0.2287
# Epoch 73/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0574 - accuracy: 0.7446 - val_loss: 4.0483 - val_accuracy: 0.1814
# Epoch 74/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0478 - accuracy: 0.7491 - val_loss: 5.3161 - val_accuracy: 0.1233
# Epoch 75/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0499 - accuracy: 0.7445 - val_loss: 4.5766 - val_accuracy: 0.1643
# Epoch 76/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.0326 - accuracy: 0.7499 - val_loss: 4.2202 - val_accuracy: 0.1299
# Epoch 77/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0511 - accuracy: 0.7416 - val_loss: 1.7745 - val_accuracy: 0.4833
# Epoch 78/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0395 - accuracy: 0.7508 - val_loss: 3.6438 - val_accuracy: 0.2697
# Epoch 79/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0324 - accuracy: 0.7511 - val_loss: 6.5977 - val_accuracy: 0.1032
# Epoch 80/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.0413 - accuracy: 0.7470 - val_loss: 6.3531 - val_accuracy: 0.1336
# Epoch 81/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0386 - accuracy: 0.7478 - val_loss: 5.2036 - val_accuracy: 0.1730
# Epoch 82/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0304 - accuracy: 0.7507 - val_loss: 6.9877 - val_accuracy: 0.1820
# Epoch 83/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0368 - accuracy: 0.7447 - val_loss: 26.6549 - val_accuracy: 0.1797
# Epoch 84/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.0264 - accuracy: 0.7536 - val_loss: 8.4774 - val_accuracy: 0.1416
# Epoch 85/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0153 - accuracy: 0.7549 - val_loss: 7.1080 - val_accuracy: 0.1770
# Epoch 86/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0258 - accuracy: 0.7525 - val_loss: 8.7894 - val_accuracy: 0.1014
# Epoch 87/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0661 - accuracy: 0.7524 - val_loss: 5.9403 - val_accuracy: 0.1290
# Epoch 88/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.0560 - accuracy: 0.7452 - val_loss: 2.5743 - val_accuracy: 0.3655
# Epoch 89/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0177 - accuracy: 0.7522 - val_loss: 7.5258 - val_accuracy: 0.1335
# Epoch 90/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0434 - accuracy: 0.7422 - val_loss: 4.7131 - val_accuracy: 0.2191
# Epoch 91/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0355 - accuracy: 0.7462 - val_loss: 5.7203 - val_accuracy: 0.1936
# Epoch 92/100
# 1250/1250 [==============================] - 17s 14ms/step - loss: 1.0364 - accuracy: 0.7485 - val_loss: 3.2289 - val_accuracy: 0.3233
# Epoch 93/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0242 - accuracy: 0.7513 - val_loss: 5.1271 - val_accuracy: 0.2725
# Epoch 94/100
# 1250/1250 [==============================] - 17s 14ms/step - loss: 1.0333 - accuracy: 0.7503 - val_loss: 5.5199 - val_accuracy: 0.2331
# Epoch 95/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0092 - accuracy: 0.7593 - val_loss: 9.2310 - val_accuracy: 0.1186
# Epoch 96/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0188 - accuracy: 0.7558 - val_loss: 3.3061 - val_accuracy: 0.1708
# Epoch 97/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0060 - accuracy: 0.7566 - val_loss: 4.4933 - val_accuracy: 0.1508
# Epoch 98/100
# 1250/1250 [==============================] - 17s 13ms/step - loss: 1.0414 - accuracy: 0.7425 - val_loss: 3.4033 - val_accuracy: 0.2638
# Epoch 99/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0271 - accuracy: 0.7546 - val_loss: 6.2492 - val_accuracy: 0.1060
# Epoch 100/100
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.0189 - accuracy: 0.7548 - val_loss: 8.2989 - val_accuracy: 0.1115

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss performance')
plt.legend(['train loss', 'validation loss'])
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy performance')
plt.legend(['train accuracy', 'validation accuracy'])
plt.show()

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 8.3330 - accuracy: 0.1089
# [8.332992553710938, 0.10890000313520432]
